# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravprajapati9210/Machine-Learning-Projects/blob/main/Rock_vs_Mine_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection and Data Processing

# %%
#loading the dataset to a pandas Dataframe
sonar_data = pd.read_csv('/content/sonar_data.csv', header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
#number of rows and columns
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe  #Describe gives statistical measures of the data
# Out:
# <bound method NDFrame.describe of          0       1       2       3       4   ...      56      57      58      59  60
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ...  ..
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157   M
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067   M
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031   M
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048   M
# ...

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# M--> Mine
# R -->Rock

# %%
 sonar_data.groupby(60).mean()
# Out:
#           0         1         2   ...        57        58        59
# 60                                ...
# M   0.034989  0.045544  0.050720  ...  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  ...  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
#Seperating data and labels

X = sonar_data.drop(columns=60,axis=1)
Y = sonar_data[60]

# %%
print(X,Y)
# Out:
#          0       1       2       3   ...      56      57      58      59
# 0    0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 1    0.0453  0.0523  0.0843  0.0689  ...  0.0140  0.0049  0.0052  0.0044
# 2    0.0262  0.0582  0.1099  0.1083  ...  0.0316  0.0164  0.0095  0.0078
# 3    0.0100  0.0171  0.0623  0.0205  ...  0.0050  0.0044  0.0040  0.0117
# 4    0.0762  0.0666  0.0481  0.0394  ...  0.0072  0.0048  0.0107  0.0094
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 204  0.0323  0.0101  0.0298  0.0564  ...  0.0034  0.0032  0.0062  0.0067
# 205  0.0522  0.0437  0.0180  0.0292  ...  0.0140  0.0138  0.0077  0.0031
# 206  0.0303  0.0353  0.0490  0.0608  ...  0.0034  0.0079  0.0036  0.0048
# 207  0.0260  0.0363  0.0136  0.0272  ...  0.0040  0.0036  0.0061  0.0115
#
# [208 rows x 60 columns] 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# ...

# %% [markdown]
# Training and Test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %% [markdown]
# Model Training --> Logistic Regression

# %%
model2= LogisticRegression()

# %%
#Training model LogisticRegression model with training data
model2.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
#Accuracy on training data
X_train_prediction = model2.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy of training data=",training_data_accuracy )
# Out:
# Accuracy of training data= 0.8342245989304813

# %% [markdown]
# Making a Predictive System

# %%
input_data = (0.0108,0.0086,0.0058,0.0460,0.0752,0.0887,0.1015,0.0494,0.0472,0.0393,0.1106,0.1412,0.2202,0.2976,0.4116,0.4754,0.5390,0.6279,0.7060,0.7918,0.9493,1.0000,0.9645,0.9432,0.8658,0.7895,0.6501,0.4492,0.4739,0.6153,0.4929,0.3195,0.3735,0.3336,0.1052,0.0671,0.0379,0.0461,0.1694,0.2169,0.1677,0.0644,0.0159,0.0778,0.0653,0.0210,0.0509,0.0387,0.0262,0.0101,0.0161,0.0029,0.0078,0.0114,0.0083,0.0058,0.0003,0.0023,0.0026,0.0027)

#reshape the numpy array as we are predictiong for one instance

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = model2.predict(input_data_reshaped)
print(prediction)
# Out:
# ['M']
